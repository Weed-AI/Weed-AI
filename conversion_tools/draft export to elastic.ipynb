# %%
import json

# %%
coco = json.load(open("cwfid_imageinfo.json"))
del coco['info']
del coco['collection_memberships']

# %%
coco.keys()
# Out:
# dict_keys(['images', 'annotations', 'categories', 'license', 'agcontexts', 'collections'])

# %%
id_lookup = {}
for key, objs in coco.items():
    print(key)
    for obj in objs:
        id_lookup[key, obj['id']] = obj
# Out:
# images
# annotations
# categories
# license
# agcontexts
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-bad0e0138971> in <module>()
#       3     print(key)
#       4     for obj in objs:
# ----> 5         id_lookup[key, obj['id']] = obj
#
# KeyError: 'id'

# %%
for annotation in coco['annotations']:
    image = id_lookup['images', annotation['image_id']]
    image.setdefault('annotations', []).append(annotation)
    annotation['category'] = id_lookup['categories', annotation['category_id']]
    annotation['agcontext'] = id_lookup['agcontexts', annotation['agcontext_id']]
    # todo: add collection, license
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-0742b733fcbe> in <module>()
#       3     image.setdefault('annotations', []).append(annotation)
#       4     annotation['category'] = id_lookup['categories', annotation['category_id']]
# ----> 5     annotation['agcontext'] = id_lookup['agcontexts', annotation['agcontext_id']]
#       6     # todo: add collection, license
#
# KeyError: 'agcontext_id'

# %%
coco['images'][0]
# Out:
# {'annotations': [{'agcontext': {'agcontext_name': 'deepweeds',
#     'camera_angle': 90,
#     'camera_fov': 85,
#     'camera_height': 100,
#     'camera_type': 'weedlogger',
#     'crop_type': 'pastoral_grassland',
#     'emr_channels': 'na',
#     'id': 0,
#     'upload_time': '2020-07-15 17:09:49',
#     'url': 'https://github.com/AlexOlsen/DeepWeeds'},
#    'agcontext_id': 0,
#    'agcontext_name': 'deepweeds',
#    'category': {'common_name': 'chinee apple',
#     'eppo_taxon_code': 'ZIPMA',
#     'id': 0,
#     'role': 'weed',
#     'species': 'ziziphus mauritiana'},
#    'category_id': 0,
#    'id': '28ffa7a4-c66a-11ea-9851-acde48001122',
#    'image_id': '20160928-140314-0.jpg'}],
#  'file_name': 'deepweeds_to_json/deepweeds_images_full/20160928-140314-0.jpg',
#  'height': 256,
#  'id': '20160928-140314-0.jpg',
#  'license': 0,
#  'resolution': 65536,
#  'width': 256}

# %%
coco['agcontexts']
# Out:
# [{'agcontext_name': 'deepweeds',
#   'camera_angle': 90,
#   'camera_fov': 85,
#   'camera_height': 100,
#   'camera_type': 'weedlogger',
#   'crop_type': 'pastoral_grassland',
#   'emr_channels': 'na',
#   'id': 0,
#   'upload_time': '2020-07-15 17:09:49',
#   'url': 'https://github.com/AlexOlsen/DeepWeeds'}]

# %%
with open("export-for-elastic.json-ld", 'w') as f:
    f.write('\n')
    for image in coco['images']:
        json.dump({ "index":{ "_index": "weedid", "_type": "image" } }, f)
        f.write('\n')
        json.dump(image, f)
        f.write('\n')

# %%
# !cat export-for-elastic.json-ld
# Out:
# {"index": {"_index": "weedid", "_type": "image"}}
# {"id": "20160928